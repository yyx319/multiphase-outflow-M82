# %%
import sys
sys.path.append('/Users/yuxuan/Documents/Research_module/despotic')
import numpy as np
import matplotlib.pyplot as plt
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
from matplotlib.colors import LogNorm
from scipy.optimize import brentq
import matplotlib.cm as cm
import matplotlib.colors as colors
from despotic import emitter
from despotic.winds import pwind, zetaM, sxMach
from astropy.io import fits
# Constants; switch to cgs
from scipy.constants import G, c, m_p, m_e, h
from scipy.constants import k as kB
from astropy.units import Msun, yr, Angstrom, pc
# interact
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import emcee

import wind_obs_diag_pkg as wodp
import wind_obs_diag_pkg_interact as wodpi

# directory of data
dat_dir = 'wind_data'

#import yt
c = 1e2*c
hP = h*1e7
G = 1e3*G
kB = 1e7*kB
mH = (m_e + m_p)*1e3
muH = 1.4
Msun = Msun.to('g')
yr = yr.to('s')
Myr = 1e6*yr
Gyr = 1e9*yr
ang = Angstrom.to('cm')
pc = pc.to('cm')
kpc = 1e3*pc
# Fiducial parameters
mdotstar = 4.1*Msun/yr
epsff = 0.01
mach = 100.0
uh = 10.0
v0 = 120e5*np.sqrt(2)
r0 = 250*pc
m0 = v0**2*r0/(2.0*G)
rho0 = 3.0*m0/(4.0*np.pi*r0**3)
tc = r0/v0
temp = 50.
dist = 3.5e3*kpc

# %%
# emission line data
obj = 'M82'
#3.6Mpc (Freedman et al. 1994) so that 1''=17.5 pc and 1'=1 kpc
# systematic velocity 211 km/s 

# emission  Warm ionized gas
# Ha Martin98 
# north pos_a~1kpc
print('Halpha')
Ha = fits.open('%s/%s/Martin98/NGC_3034_I_Ha_d2009.fits'%(dat_dir, obj))

l_n, Ha_n = np.loadtxt('%s/%s/Martin98/M82_north.txt'%(dat_dir, obj), usecols=(0,1), unpack=True, skiprows=1)
Ha_n_e = np.loadtxt('%s/%s/Martin98/M82_north_rms.txt'%(dat_dir, obj), usecols=(1), unpack=True,skiprows=1)
l_s, Ha_s = np.loadtxt('%s/%s/Martin98/M82_south.txt'%(dat_dir, obj), usecols=(0,1), unpack=True,skiprows=1)
Ha_s_e = np.loadtxt('%s/%s/Martin98/M82_south_rms.txt'%(dat_dir, obj), usecols=(1), unpack=True,skiprows=1)
v_n = (l_n/6562.801-1)*c/1.e5
v_s = (l_s/6562.801-1)*c/1.e5


# infomation on the data

# 0.43'' (0.43''*17.5pc = 7.525 pc)
print('Halpha')
print(Ha.info(),'\n')
print([Ha[0].header])
print(Ha[0].__dict__.keys(),'\n\n')
Ha = Ha[0].data
# Out:
# Halpha
# Halpha
# Filename: wind_data/M82/Martin98/NGC_3034_I_Ha_d2009.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     143   (679, 681)   float32
# None
#
# [SIMPLE  =                    T / Fits standard
# BITPIX  =                  -32 / Bits per pixel
# NAXIS   =                    2 / Number of axes
# NAXIS1  =                  679 / Axis length
# NAXIS2  =                  681 / Axis length
# EXTEND  =                    F / File may contain extensions
# ORIGIN  = 'NOAO-IRAF FITS Image Kernel July 2003' / FITS file originator
# IRAF-TLM= '14:29:18 (09/12/2009)'
# OBJECT  = 'M82 653 '           /
# DATE    = '2008-02-05T20:21:43'
# IRAF-MAX=           0.000000E0  /  DATA MAX
# IRAF-MIN=           0.000000E0  /  DATA MIN
# OBSERVAT= 'KPNO              '  /  observatory
# OBSERVER= 'RCK,SS,SA,DM      '  /  observers
# EXPTIME =                 600.  /  actual integration time
# DARKTIME=                 600.  /  total elapsed time
# IMAGETYP= 'object            '  /  object, dark, bias, etc.
# DATE-OBS= '2001-05-30        '  /  date (dd/mm/yy) of obs.
# UT      = '03:49:59          '  /  universal time
# ST      = '12:54:22          '  /  sidereal time
# RA      = '09:55:52.44       '  /  right ascension
# DEC     = '+69:40:19.6       '  /  declination
# ZD      = '45.299999         '  /  zenith distance
# AIRMASS =                 1.42  /  airmass
# TELFILTE= '653               '  /  telescope filters
# TELESCOP= 'bok               '  /  telescope name
# DETECTOR= 'ccd21             '  /  detector
# PREFLASH=                    0  /  preflash time, seconds
# GAIN    =                  3.4  /  gain, electrons per adu
# DWELL   =                   50  /  sample integration time
# RDNOISE =                  8.5  /  read noise, electrons
# CAMTEMP =                 -119  /  camera temperature
# DEWTEMP =                 -189  /  dewar temperature
# CCDSEC  = '[4:682,2:682]'       /  orientation to full frame
# ORIGSEC = '[1:682,1:682]     '  /  original size full frame
# CCDSUM  = '3 3               '  /  on chip summation
# INSTRUME= 'direct            '  /  instrument
# DISPAXIS= '1                 '  /  dispersion axis
# WCSDIM  =                    2
# LTM1_1  =                   1.
# LTM2_2  =                   1.
# WAT0_001= 'system=image'
# WAT1_001= 'wtype=tan axtype=ra'
# WAT2_001= 'wtype=tan axtype=dec'
# TRIM    = 'Nov  5 15:04 Trim data section is [4:682,2:682]'
# FIXPIX  = 'Nov  5 15:04 Bad pixel file is badpix'
# OVERSCAN= 'Nov  5 15:04 Overscan section is [683:702,1:682] with mean=443.0652'
# ZEROCOR = 'Nov  5 15:04 Zero level correction image is Zero.n9.imh'
#
#
# COMMENT PROCESSING INFORMATION
# LTV1    =    -4.66999995708466
# LTV2    =   0.0499999523162842
# CCDPROC = 'Nov  5 15:04 CCD processing done'
# HISTORY New copy of a.0913.imh
# HISTORY New copy of /net/bok/d1/bokobs/archive/a.0913.imh
# HISTORY New copy of /d1/robk/may01.d/a.0913.imh
# HISTORY New copy of a.0913.imh
# HISTORY New copy of a.0913
# HISTORY New copy of test1
# HISTORY New copy of f.M82
# HISTORY New copy of f.M82.imh
# FIXPIX02= 'Jan 22 17:05 Bad pixel file is mask'
# FIXPIX03= 'Jan 22 17:07 Bad pixel file is mask'
# AGCNUM  =                    0
# SPIN    =                    0
# CCDSCALE=               0.4347
# CCDNOISE=                  8.5
# FILTER  =                  658
# ORIENTNE= '0.,90.  '
# CAIRMASS=             1.424096
# UTMIDDLE= '3:54:59.0'
# ID      =                  146
#
# COMMENT EMISSION-LINE FLUX CALIBRATION (Kennicutt et al. 2008 Appendix )
# SCALE_R =                  3.4  /R-band image divisor
# ZP      =               21.127  /Zeropoint
# K       =                 0.08  /Assumed atmospheric extinction coefficient
# VHELIO  =                  203  /NED heliocentric recessional velocity
# MAG_I_HA=              -12.591  /Instrumental Ha+[NII] magnitude
# MAG_I_R =              -14.735  /Instrumental continuum magnitude
# FWHM_HA =                 68.7  /Narrowband FWHM
# FWHM_R  =               1539.1  /R-band FWHM
# RESPONSE=  6.8665113015279E-16  /Unit response (counts/s/ergs/s/cm^2/A)
# TRANSMIS=    0.921882352941176  /Narrowband effective transmission
# FLUX_CAL=    -10.0915392873649  /LOG flux(Ha+[NII]) ergs/s/cm^2
# EW      =      64.336516126881  /EW(Ha+[NII]) (Angstrom)
#
#
#
# COMMENT ASTROMETRIC SOLUTION
# CTYPE1  = 'RA---TAN'
# CTYPE2  = 'DEC--TAN'
# CRVAL1  =     148.957885939181
# CRVAL2  =     69.6821869104213
# CRPIX1  =      367.99243626297
# CRPIX2  =     354.685449876616
# CD1_1   =  -1.1984747411472E-4
# CD1_2   =  2.12247177656580E-6
# CD2_1   =  2.11605520734021E-6
# CD2_2   =  1.19732963229223E-4
# RADECSYS= 'FK5     '
# EQUINOX =                2000.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                                                 ]
# ['_scale_back', '_orig_blank', '_orig_bzero', '_bitpix', '_do_not_scale_image_data', '_header', '_buffer', '_data_size', '_axes', '_modified', '_header_offset', '_new', '_gcount', '_file', '_orig_bscale', '_data_needs_rescale', '_bzero', '_bscale', '_blank', '_uint', '_orig_bitpix', '_data_offset', '_data_replaced', '_output_checksum', '_pcount']

# %%
# total luminosity
import astropy.constants as c; import astropy.units as u; 

area = (0.43/3600.*np.pi/180.)**2 # in rad**2
area_pix = (0.43*17.5*u.pc)**2
area_tot = 679*681*area_pix 

print('area of pixel in rad^2: %e rad'%area)

flux = 10**(-10.0915)*u.erg/u.s/u.cm**2

# total luminosity
D = 3.6*u.Mpc
L = flux*D**2*4*np.pi
L = L.to(u.erg/u.s)
logL = np.log10(L.value)
print('logrithmic of Luminosity of source in erg/s: %f'%logL)
# Out:
# area of pixel in rad^2: 4.345969e-12 rad
# logrithmic of Luminosity of source in erg/s: 41.099016

# %% [markdown]
# ### surface brightness
# $$
# SB_{\rm pix} = \frac{L_{\rm tot} }{A_{\rm pix}} \frac{counts_{\rm pix}}{counts_{\rm tot}} = \frac{4 \pi F_{\rm tot} }{ [0.43'' \mathrm{in \space rad}]^2 } \frac{counts_{\rm pix}}{counts_{\rm tot}}
# $$

# %% [markdown]
# $$ c_\rho = \frac{\langle n^2 \rangle}{\langle n\rangle^2}$$
#
# $$ \mathrm{SB} = \frac{ \alpha_{\rm H\alpha} e_{\rm H\alpha} D_{\rm LOS} \langle n^2 \rangle }{c_\rho} = \alpha_{\rm H\alpha} e_{\rm H\alpha} D_{\rm LOS} \langle n \rangle ^2 $$
#
# $$ c_\rho = \frac{ \alpha_{\rm H\alpha} e_{\rm H\alpha} D_{\rm LOS} \langle n^2 \rangle }{ \mathrm{SB} }$$

# %%
lam = 4681*u.Angstrom
e = c.h*c.c/lam
print( e.to(u.erg) )# Halpha energy

# in cgs
alpha_ha = 4e-13
e_ha = 3.03e-12 
SB = 4*np.pi*5.04e-4 # in erg/s/cm^2
D = 1*kpc
n_rms = 0.1 # root mean square density
c_rho = SB/alpha_ha/e_ha/D/n_mean**2 
print('clumping factor %f'%c_rho)
# Out:
# 169.350793316

# %%
# mean density
n_m = np.sqrt(SB/alpha_ha/e_ha/D)
n_m
# Out:
# 1.3013485056519902

# %%
Ha[340+n_1, 340+n_2]/tot_count
# Out:
# 2.1504231e-06

# %%
#surface brightness
tot_count = np.sum(Ha)
tot_count
thres = np.max(Ha)/100
np.sum(Ha[Ha>thres])/tot_count

# total flux 10**(-10.0915) ergs/s/cm^2
norm = 10.**(-10.0915)/23962321.5
#area = (0.43/3600.*np.pi/180.)**2 # in rad^2 = Sr
area = 0.43**2 # in arcsec^2 
SB_n = norm*Ha[340+n_1, 340+n_2]/area/1.3 # in erg/s/cm^2
SB_s = norm*Ha[340-n_1, 340-n_2]/area/1.3

print(SB_n)
# Out:
# 2.1982809593143372e-15

# %%
norm*Ha_rot[180, 180+133]/area/1.3
# Out:
# 1.9846395993667296e-15

# %%
Ha_rot, n_g, n_g = wodp.rotate(Ha, center=(325,345), angle=-23, n_g=360, dim=2 )

# %%
sp_r = 0.43*17.5*n_g/1000 # in kpc

# in erg/s/cm^2/arcsec^2

print(1)
plt.imshow(norm*Ha_rot/area/1.3, norm=LogNorm(), origin='lower', extent=[-sp_r/2.,sp_r/2., -sp_r/2.,sp_r/2.])
plt.colorbar()

print(SB_n)

plt.figure(2)
#norm = 10.**(-10.0915)/63962321.5
norm = 10.**(-10.0915)/24638232.0
area = 0.43**2 # in arcsec^2 
plt.contour(norm*Ha_rot/area/1.3, [np.logspace(-15.5, -12.5, 7)], norm=LogNorm(), origin='lower',
            extent=[-sp_r/2.,sp_r/2., -sp_r/2.,sp_r/2.])
plt.colorbar()
#plt.title(r'H$\alpha$ flux [$erg/s/cm^2/arcsec^2$]')
#plt.savefig('flux_map.png')
# Out:
# 1
# 2.1982809593143372e-15

# %%
#surface brightness
tot_count = np.sum(Ha)
tot_count
thres = np.max(Ha)/100
np.sum(Ha[Ha>thres])/tot_count

n_kpc = int(1000./7.525)
# total flux 10**(-10.0915) ergs/s/cm^2
norm = 10.**(-10.0915)/23962321.5
#area = (0.43/3600.*np.pi/180.)**2 # in rad^2 = Sr
area = 0.43**2 # in arcsec^2 
SB_n = norm*Ha_rot[180, 180+n_kpc]/area/1.3 # in erg/s/cm^2
SB_s = norm*Ha_rot[180, 180-n_kpc]/area/1.3

print(SB_n)
print(SB_n)
# Out:
# 3.0383915689300046e-15

# %% [markdown]
# ### H$\alpha$ spectra

# %%
fig, axs = plt.subplots(2,1, figsize=(6, 9))
axs[0].semilogy(v_n-211, Ha_n)
axs[0].fill_between(v_n-211, Ha_n-np.abs(Ha_n_e), Ha_n+np.abs(Ha_n_e))
axs[0].axis([-400,400,1e1,2e2])
axs[1].semilogy(v_s-211, Ha_s)
axs[1].fill_between(v_s-211, Ha_s-np.abs(Ha_s_e), Ha_s+np.abs(Ha_s_e))
axs[1].axis([-600,200,1e1,2e2])
plt.savefig('Halpha_spct.png')
